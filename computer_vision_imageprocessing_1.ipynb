# %% [markdown]
# <a href="https://colab.research.google.com/github/j-agrawal/computer_vision/blob/master/computer_vision_imageprocessing_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# checking version
cv2.__version__
# Out:
# '3.4.3'

# %%
# images reading

img = cv2.imread('IMG_20190114_131938.jpg')

# %%
# print image
img
# Out:
# array([[[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
#         ...,
#         [255, 221, 163],
#         [255, 221, 163],
#         [255, 221, 163]],
#
#        [[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
#         ...,
#         [255, 221, 163],
#         [255, 221, 163],
#         [255, 221, 163]],
#
#        [[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
#         ...,
#         [255, 221, 163],
#         [255, 221, 163],
#         [255, 221, 163]],
#
#        ...,
#
#        [[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
#         ...,
#         [ 59,  59,  77],
#         [ 59,  59,  75],
#         [ 58,  58,  74]],
#
#        [[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
#         ...,
#         [ 59,  59,  77],
#         [ 59,  59,  75],
#         [ 59,  60,  74]],
#
#        [[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
# ...

# %%
# print shape 
img.shape
# here first thing is height second is width and third is colour channel(BGR or RGB)
# Out:
# (5184, 3880, 3)

# %%
# type
type(img)
# Out:
# numpy.ndarray

# %%
from google.colab.patches import cv2_imshow

# %%
# to display image
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
